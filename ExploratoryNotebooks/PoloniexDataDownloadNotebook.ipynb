# %%
from PoloniexAPI import *
import json

with open("secrets.json") as f:
    secrets = json.load(f)
    
api = poloniex(secrets['poloniex']['key'], secrets['poloniex']['secret'])

# %%
tickers = api.returnTicker()
# Out:
# /home/nburns/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
tickers
# Out:
# {'BTC_AMP': {'baseVolume': '12.54799686',
#   'high24hr': '0.00003600',
#   'highestBid': '0.00003526',
#   'id': 160,
#   'isFrozen': '0',
#   'last': '0.00003546',
#   'low24hr': '0.00003406',
#   'lowestAsk': '0.00003546',
#   'percentChange': '0.00824566',
#   'quoteVolume': '359650.31192298'},
#  'BTC_ARDR': {'baseVolume': '39.01138205',
#   'high24hr': '0.00004488',
#   'highestBid': '0.00004397',
#   'id': 177,
#   'isFrozen': '0',
#   'last': '0.00004396',
#   'low24hr': '0.00004000',
#   'lowestAsk': '0.00004448',
#   'percentChange': '0.07983296',
#   'quoteVolume': '935304.44216028'},
#  'BTC_BCH': {'baseVolume': '128.14974719',
#   'high24hr': '0.09751086',
#   'highestBid': '0.09725013',
#   'id': 189,
#   'isFrozen': '0',
#   'last': '0.09725013',
#   'low24hr': '0.09467532',
#   'lowestAsk': '0.09739995',
#   'percentChange': '0.02444042',
#   'quoteVolume': '1332.60059296'},
#  'BTC_BCN': {'baseVolume': '121.50782995',
#   'high24hr': '0.00000055',
#   'highestBid': '0.00000051',
#   'id': 7,
#   'isFrozen': '0',
#   'last': '0.00000052',
#   'low24hr': '0.00000047',
#   'lowestAsk': '0.00000052',
#   'percentChange': '0.06122448',
#   'quoteVolume': '234845503.98258355'},
#  'BTC_BCY': {'baseVolume': '4.93403621',
#   'high24hr': '0.00004861',
#   'highestBid': '0.00004615',
#   'id': 151,
#   'isFrozen': '0',
#   'last': '0.00004613',
#   'low24hr': '0.00004492',
#   'lowestAsk': '0.00004662',
#   'percentChange': '0.02397336',
#   'quoteVolume': '106560.56737139'},
#  'BTC_BELA': {'baseVolume': '3.04450517',
#   'high24hr': '0.00001245',
#   'highestBid': '0.00001227',
#   'id': 8,
#   'isFrozen': '0',
#   'last': '0.00001227',
#   'low24hr': '0.00001201',
#   'lowestAsk': '0.00001228',
#   'percentChange': '0.00904605',
#   'quoteVolume': '248862.80099852'},
#  'BTC_BLK': {'baseVolume': '3.09054902',
#   'high24hr': '0.00003490',
#   'highestBid': '0.00003416',
#   'id': 10,
#   'isFrozen': '0',
#   'last': '0.00003453',
#   'low24hr': '0.00003341',
#   'lowestAsk': '0.00003453',
#   'percentChange': '0.00964912',
#   'quoteVolume': '90595.87960876'},
#  'BTC_BTCD': {'baseVolume': '1.09588714',
#   'high24hr': '0.00775295',
#   'highestBid': '0.00749329',
#   'id': 12,
#   'isFrozen': '0',
#   'last': '0.00761191',
#   'low24hr': '0.00719000',
#   'lowestAsk': '0.00768277',
#   'percentChange': '0.04402885',
#   'quoteVolume': '147.09452389'},
#  'BTC_BTM': {'baseVolume': '2.05129088',
#   'high24hr': '0.00007371',
#   'highestBid': '0.00007168',
#   'id': 13,
#   'isFrozen': '0',
#   'last': '0.00007262',
#   'low24hr': '0.00006963',
#   'lowestAsk': '0.00007302',
#   'percentChange': '0.02657619',
#   'quoteVolume': '28535.01145027'},
#  'BTC_BTS': {'baseVolume': '177.06273191',
#   'high24hr': '0.00002715',
#   'highestBid': '0.00002663',
#   'id': 14,
#   'isFrozen': '0',
#   'last': '0.00002671',
#   'low24hr': '0.00002590',
#   'lowestAsk': '0.00002671',
#   'percentChange': '0.00262762',
#   'quoteVolume': '6652641.88825286'},
#  'BTC_BURST': {'baseVolume': '10.07553069',
#   'high24hr': '0.00000274',
#   'highestBid': '0.00000266',
#   'id': 15,
#   'isFrozen': '0',
#   'last': '0.00000266',
#   'low24hr': '0.00000259',
#   'lowestAsk': '0.00000267',
#   'percentChange': '0.01526717',
#   'quoteVolume': '3812008.73552344'},
#  'BTC_CLAM': {'baseVolume': '3.93869601',
#   'high24hr': '0.00052226',
#   'highestBid': '0.00051745',
#   'id': 20,
#   'isFrozen': '0',
#   'last': '0.00051745',
#   'low24hr': '0.00050197',
#   'lowestAsk': '0.00052000',
#   'percentChange': '0.02713486',
#   'quoteVolume': '7668.67869530'},
#  'BTC_CVC': {'baseVolume': '8.68862405',
#   'high24hr': '0.00004378',
#   'highestBid': '0.00004370',
#   'id': 194,
#   'isFrozen': '0',
#   'last': '0.00004370',
#   'low24hr': '0.00004181',
#   'lowestAsk': '0.00004376',
#   'percentChange': '0.02365893',
#   'quoteVolume': '204051.09370221'},
#  'BTC_DASH': {'baseVolume': '199.43534723',
#   'high24hr': '0.04703543',
#   'highestBid': '0.04655659',
#   'id': 24,
#   'isFrozen': '0',
#   'last': '0.04654748',
#   'low24hr': '0.04498419',
#   'lowestAsk': '0.04655660',
#   'percentChange': '0.03454293',
#   'quoteVolume': '4321.92397503'},
#  'BTC_DCR': {'baseVolume': '21.99533695',
#   'high24hr': '0.00788429',
#   'highestBid': '0.00759999',
#   'id': 162,
#   'isFrozen': '0',
#   'last': '0.00760000',
#   'low24hr': '0.00757560',
#   'lowestAsk': '0.00760000',
#   'percentChange': '-0.01375679',
#   'quoteVolume': '2859.77207381'},
#  'BTC_DGB': {'baseVolume': '127.07644875',
#   'high24hr': '0.00000383',
#   'highestBid': '0.00000378',
#   'id': 25,
#   'isFrozen': '0',
#   'last': '0.00000378',
#   'low24hr': '0.00000358',
#   'lowestAsk': '0.00000380',
#   'percentChange': '0.02717391',
#   'quoteVolume': '34123347.64697042'},
#  'BTC_DOGE': {'baseVolume': '365.61209949',
#   'high24hr': '0.00000062',
#   'highestBid': '0.00000060',
#   'id': 27,
#   'isFrozen': '0',
#   'last': '0.00000061',
#   'low24hr': '0.00000057',
#   'lowestAsk': '0.00000061',
#   'percentChange': '0.05172413',
#   'quoteVolume': '610331088.64774060'},
#  'BTC_EMC2': {'baseVolume': '151.58754757',
#   'high24hr': '0.00004500',
#   'highestBid': '0.00004103',
#   'id': 28,
#   'isFrozen': '0',
#   'last': '0.00004113',
#   'low24hr': '0.00003018',
#   'lowestAsk': '0.00004113',
#   'percentChange': '0.33756097',
#   'quoteVolume': '4010474.91972216'},
#  'BTC_ETC': {'baseVolume': '113.49125147',
#   'high24hr': '0.00207000',
#   'highestBid': '0.00203892',
#   'id': 171,
#   'isFrozen': '0',
#   'last': '0.00203890',
#   'low24hr': '0.00200111',
#   'lowestAsk': '0.00203937',
#   'percentChange': '0.00790445',
#   'quoteVolume': '55739.69528265'},
#  'BTC_ETH': {'baseVolume': '730.33134748',
#   'high24hr': '0.06406223',
#   'highestBid': '0.06389521',
#   'id': 148,
#   'isFrozen': '0',
#   'last': '0.06392204',
#   'low24hr': '0.06285753',
#   'lowestAsk': '0.06392204',
#   'percentChange': '0.01134467',
#   'quoteVolume': '11461.73612835'},
#  'BTC_EXP': {'baseVolume': '18.20860517',
#   'high24hr': '0.00028715',
#   'highestBid': '0.00025677',
#   'id': 153,
#   'isFrozen': '0',
#   'last': '0.00025928',
#   'low24hr': '0.00024276',
#   'lowestAsk': '0.00025928',
#   'percentChange': '0.06131805',
#   'quoteVolume': '68920.28431080'},
#  'BTC_FCT': {'baseVolume': '81.71765023',
#   'high24hr': '0.00350000',
#   'highestBid': '0.00339917',
#   'id': 155,
#   'isFrozen': '0',
#   'last': '0.00339654',
#   'low24hr': '0.00330213',
#   'lowestAsk': '0.00340082',
#   'percentChange': '0.02811427',
#   'quoteVolume': '23887.57585753'},
#  'BTC_FLDC': {'baseVolume': '7.43868591',
#   'high24hr': '0.00000244',
#   'highestBid': '0.00000239',
#   'id': 31,
#   'isFrozen': '0',
#   'last': '0.00000242',
#   'low24hr': '0.00000218',
#   'lowestAsk': '0.00000242',
#   'percentChange': '0.10000000',
#   'quoteVolume': '3203341.03352175'},
#  'BTC_FLO': {'baseVolume': '6.44789741',
#   'high24hr': '0.00001087',
#   'highestBid': '0.00001075',
#   'id': 32,
#   'isFrozen': '0',
#   'last': '0.00001087',
#   'low24hr': '0.00000957',
#   'lowestAsk': '0.00001087',
#   'percentChange': '0.11258955',
#   'quoteVolume': '625669.97655937'},
#  'BTC_GAME': {'baseVolume': '16.12029220',
#   'high24hr': '0.00021120',
#   'highestBid': '0.00020915',
#   'id': 38,
#   'isFrozen': '0',
#   'last': '0.00021120',
#   'low24hr': '0.00019818',
#   'lowestAsk': '0.00021119',
#   'percentChange': '0.04497550',
#   'quoteVolume': '78486.64842615'},
#  'BTC_GAS': {'baseVolume': '4.44405552',
#   'high24hr': '0.00263609',
#   'highestBid': '0.00258440',
#   'id': 198,
#   'isFrozen': '0',
#   'last': '0.00261868',
#   'low24hr': '0.00250070',
#   'lowestAsk': '0.00262201',
#   'percentChange': '0.04238101',
#   'quoteVolume': '1720.74160481'},
#  'BTC_GNO': {'baseVolume': '25.85925921',
#   'high24hr': '0.01318539',
#   'highestBid': '0.01235867',
#   'id': 187,
#   'isFrozen': '0',
#   'last': '0.01249350',
#   'low24hr': '0.01181473',
#   'lowestAsk': '0.01249350',
#   'percentChange': '0.04112500',
#   'quoteVolume': '2081.29891577'},
#  'BTC_GNT': {'baseVolume': '56.61387422',
#   'high24hr': '0.00005466',
#   'highestBid': '0.00005372',
#   'id': 185,
#   'isFrozen': '0',
#   'last': '0.00005372',
#   'low24hr': '0.00004996',
#   'lowestAsk': '0.00005389',
#   'percentChange': '0.06481665',
#   'quoteVolume': '1087036.45878027'},
#  'BTC_GRC': {'baseVolume': '1.16118457',
#   'high24hr': '0.00000580',
#   'highestBid': '0.00000576',
#   'id': 40,
#   'isFrozen': '0',
#   'last': '0.00000576',
#   'low24hr': '0.00000558',
#   'lowestAsk': '0.00000578',
#   'percentChange': '0.02127659',
#   'quoteVolume': '202578.25382322'},
#  'BTC_HUC': {'baseVolume': '1.16425183',
#   'high24hr': '0.00001481',
#   'highestBid': '0.00001435',
#   'id': 43,
#   'isFrozen': '0',
#   'last': '0.00001446',
#   'low24hr': '0.00001376',
#   'lowestAsk': '0.00001446',
#   'percentChange': '0.01974612',
#   'quoteVolume': '81378.29818505'},
#  'BTC_LBC': {'baseVolume': '10.57804225',
#   'high24hr': '0.00003387',
#   'highestBid': '0.00003297',
#   'id': 167,
#   'isFrozen': '0',
#   'last': '0.00003295',
#   'low24hr': '0.00003050',
#   'lowestAsk': '0.00003338',
#   'percentChange': '0.07504078',
#   'quoteVolume': '332695.70633684'},
#  'BTC_LSK': {'baseVolume': '80.52490512',
#   'high24hr': '0.00137322',
#   'highestBid': '0.00131139',
#   'id': 163,
#   'isFrozen': '0',
#   'last': '0.00132015',
#   'low24hr': '0.00129381',
#   'lowestAsk': '0.00132006',
#   'percentChange': '0.00390871',
#   'quoteVolume': '60086.86755654'},
#  'BTC_LTC': {'baseVolume': '591.00100546',
#   'high24hr': '0.01730000',
#   'highestBid': '0.01723523',
#   'id': 50,
#   'isFrozen': '0',
#   'last': '0.01723073',
#   'low24hr': '0.01613544',
#   'lowestAsk': '0.01723524',
#   'percentChange': '0.06265252',
#   'quoteVolume': '34983.09788532'},
#  'BTC_MAID': {'baseVolume': '26.86315995',
#   'high24hr': '0.00004404',
#   'highestBid': '0.00004285',
#   'id': 51,
#   'isFrozen': '0',
#   'last': '0.00004318',
#   'low24hr': '0.00004122',
#   'lowestAsk': '0.00004314',
#   'percentChange': '0.03573998',
#   'quoteVolume': '624337.93559297'},
#  'BTC_NAV': {'baseVolume': '16.67499108',
#   'high24hr': '0.00014608',
#   'highestBid': '0.00014228',
#   'id': 61,
#   'isFrozen': '0',
#   'last': '0.00014292',
#   'low24hr': '0.00013841',
#   'lowestAsk': '0.00014323',
#   'percentChange': '0.01253985',
#   'quoteVolume': '118646.69630716'},
#  'BTC_NEOS': {'baseVolume': '1.66505715',
#   'high24hr': '0.00035213',
#   'highestBid': '0.00035213',
#   'id': 63,
#   'isFrozen': '0',
#   'last': '0.00035213',
#   'low24hr': '0.00033901',
#   'lowestAsk': '0.00035248',
#   'percentChange': '0.02363372',
#   'quoteVolume': '4839.69716216'},
#  'BTC_NMC': {'baseVolume': '0.75571042',
#   'high24hr': '0.00021500',
#   'highestBid': '0.00021072',
#   'id': 64,
#   'isFrozen': '0',
#   'last': '0.00021317',
#   'low24hr': '0.00020779',
#   'lowestAsk': '0.00021317',
#   'percentChange': '0.01514357',
#   'quoteVolume': '3574.48717757'},
#  'BTC_NXC': {'baseVolume': '0.42385393',
#   'high24hr': '0.00001993',
#   'highestBid': '0.00001981',
#   'id': 183,
#   'isFrozen': '0',
#   'last': '0.00001981',
#   'low24hr': '0.00001942',
#   'lowestAsk': '0.00001991',
#   'percentChange': '0.00456389',
#   'quoteVolume': '21523.74372054'},
#  'BTC_NXT': {'baseVolume': '84.68859330',
#   'high24hr': '0.00002454',
#   'highestBid': '0.00002360',
#   'id': 69,
#   'isFrozen': '0',
#   'last': '0.00002350',
#   'low24hr': '0.00002288',
#   'lowestAsk': '0.00002374',
#   'percentChange': '0.01511879',
#   'quoteVolume': '3582018.72932945'},
#  'BTC_OMG': {'baseVolume': '155.18278316',
#   'high24hr': '0.00197417',
#   'highestBid': '0.00184185',
#   'id': 196,
#   'isFrozen': '0',
#   'last': '0.00184185',
#   'low24hr': '0.00180000',
#   'lowestAsk': '0.00184816',
#   'percentChange': '-0.05520959',
#   'quoteVolume': '83950.87275802'},
#  'BTC_OMNI': {'baseVolume': '3.66938843',
#   'high24hr': '0.00392100',
#   'highestBid': '0.00389713',
#   'id': 58,
#   'isFrozen': '0',
#   'last': '0.00388216',
#   'low24hr': '0.00379830',
#   'lowestAsk': '0.00391671',
#   'percentChange': '0.01007168',
#   'quoteVolume': '950.49579531'},
#  'BTC_PASC': {'baseVolume': '4.54905593',
#   'high24hr': '0.00010391',
#   'highestBid': '0.00010047',
#   'id': 184,
#   'isFrozen': '0',
#   'last': '0.00010211',
#   'low24hr': '0.00009937',
#   'lowestAsk': '0.00010234',
#   'percentChange': '0.00999010',
#   'quoteVolume': '45130.61862788'},
#  'BTC_PINK': {'baseVolume': '1.99662594',
#   'high24hr': '0.00000269',
#   'highestBid': '0.00000263',
#   'id': 73,
#   'isFrozen': '0',
#   'last': '0.00000264',
#   'low24hr': '0.00000257',
#   'lowestAsk': '0.00000264',
#   'percentChange': '0.00000000',
#   'quoteVolume': '758962.09133884'},
#  'BTC_POT': {'baseVolume': '15.92555992',
#   'high24hr': '0.00001750',
#   'highestBid': '0.00001702',
#   'id': 74,
#   'isFrozen': '0',
#   'last': '0.00001702',
#   'low24hr': '0.00001577',
#   'lowestAsk': '0.00001728',
#   'percentChange': '0.07313997',
#   'quoteVolume': '965345.46280619'},
#  'BTC_PPC': {'baseVolume': '3.61031887',
#   'high24hr': '0.00025403',
#   'highestBid': '0.00024250',
#   'id': 75,
#   'isFrozen': '0',
#   'last': '0.00024350',
#   'low24hr': '0.00023904',
#   'lowestAsk': '0.00024350',
#   'percentChange': '-0.02949382',
#   'quoteVolume': '14843.07120511'},
#  'BTC_RADS': {'baseVolume': '0.49583871',
#   'high24hr': '0.00060900',
#   'highestBid': '0.00060232',
#   'id': 158,
#   'isFrozen': '0',
#   'last': '0.00060788',
#   'low24hr': '0.00059299',
#   'lowestAsk': '0.00060900',
#   'percentChange': '0.02511003',
#   'quoteVolume': '824.41371154'},
#  'BTC_REP': {'baseVolume': '32.99938704',
#   'high24hr': '0.00372267',
#   'highestBid': '0.00370218',
#   'id': 174,
#   'isFrozen': '0',
#   'last': '0.00371000',
#   'low24hr': '0.00357698',
#   'lowestAsk': '0.00370998',
#   'percentChange': '0.02255970',
#   'quoteVolume': '9067.65392623'},
#  'BTC_RIC': {'baseVolume': '4.96233057',
#   'high24hr': '0.00001100',
#   'highestBid': '0.00001084',
#   'id': 83,
#   'isFrozen': '0',
#   'last': '0.00001094',
#   'low24hr': '0.00001035',
#   'lowestAsk': '0.00001094',
#   'percentChange': '0.03893637',
#   'quoteVolume': '460593.79497435'},
#  'BTC_SBD': {'baseVolume': '3.09452419',
#   'high24hr': '0.00030200',
#   'highestBid': '0.00030000',
#   'id': 170,
#   'isFrozen': '0',
#   'last': '0.00030154',
#   'low24hr': '0.00028000',
#   'lowestAsk': '0.00030155',
#   'percentChange': '0.03979310',
#   'quoteVolume': '10559.28382044'},
#  'BTC_SC': {'baseVolume': '294.47322576',
#   'high24hr': '0.00000237',
#   'highestBid': '0.00000229',
#   'id': 150,
#   'isFrozen': '0',
#   'last': '0.00000229',
#   'low24hr': '0.00000212',
#   'lowestAsk': '0.00000231',
#   'percentChange': '0.06018518',
#   'quoteVolume': '128980693.26919614'},
#  'BTC_STEEM': {'baseVolume': '26.68813091',
#   'high24hr': '0.00032812',
#   'highestBid': '0.00031175',
#   'id': 168,
#   'isFrozen': '0',
#   'last': '0.00031367',
#   'low24hr': '0.00030282',
#   'lowestAsk': '0.00031367',
#   'percentChange': '-0.00501189',
#   'quoteVolume': '84784.08517491'},
#  'BTC_STORJ': {'baseVolume': '25.73955529',
#   'high24hr': '0.00013778',
#   'highestBid': '0.00012911',
#   'id': 200,
#   'isFrozen': '0',
#   'last': '0.00013105',
#   'low24hr': '0.00011711',
#   'lowestAsk': '0.00013005',
#   'percentChange': '0.10190868',
#   'quoteVolume': '201804.96044685'},
#  'BTC_STR': {'baseVolume': '1269.30137836',
#   'high24hr': '0.00003970',
#   'highestBid': '0.00003875',
#   'id': 89,
#   'isFrozen': '0',
#   'last': '0.00003880',
#   'low24hr': '0.00003533',
#   'lowestAsk': '0.00003880',
#   'percentChange': '0.09419063',
#   'quoteVolume': '33429538.80848385'},
#  'BTC_STRAT': {'baseVolume': '65.75112497',
#   'high24hr': '0.00067001',
#   'highestBid': '0.00066001',
#   'id': 182,
#   'isFrozen': '0',
#   'last': '0.00066001',
#   'low24hr': '0.00060507',
#   'lowestAsk': '0.00066093',
#   'percentChange': '0.08253374',
#   'quoteVolume': '103260.46799330'},
#  'BTC_SYS': {'baseVolume': '11.31959053',
#   'high24hr': '0.00004872',
#   'highestBid': '0.00004775',
#   'id': 92,
#   'isFrozen': '0',
#   'last': '0.00004799',
#   'low24hr': '0.00004608',
#   'lowestAsk': '0.00004799',
#   'percentChange': '0.03359896',
#   'quoteVolume': '238087.61064246'},
#  'BTC_VIA': {'baseVolume': '5.91578938',
#   'high24hr': '0.00025927',
#   'highestBid': '0.00024486',
#   'id': 97,
#   'isFrozen': '0',
#   'last': '0.00024489',
#   'low24hr': '0.00023501',
#   'lowestAsk': '0.00024738',
#   'percentChange': '0.02084288',
#   'quoteVolume': '24265.36165454'},
#  'BTC_VRC': {'baseVolume': '4.38773856',
#   'high24hr': '0.00007281',
#   'highestBid': '0.00007101',
#   'id': 99,
#   'isFrozen': '0',
#   'last': '0.00007118',
#   'low24hr': '0.00006931',
#   'lowestAsk': '0.00007199',
#   'percentChange': '-0.00336040',
#   'quoteVolume': '61674.81658027'},
#  'BTC_VTC': {'baseVolume': '24.42474549',
#   'high24hr': '0.00032193',
#   'highestBid': '0.00029783',
#   'id': 100,
#   'isFrozen': '0',
#   'last': '0.00029795',
#   'low24hr': '0.00027599',
#   'lowestAsk': '0.00029800',
#   'percentChange': '0.07718727',
#   'quoteVolume': '83289.79746581'},
#  'BTC_XBC': {'baseVolume': '3.17589745',
#   'high24hr': '0.00579799',
#   'highestBid': '0.00520847',
#   'id': 104,
#   'isFrozen': '0',
#   'last': '0.00537328',
#   'low24hr': '0.00490314',
#   'lowestAsk': '0.00537320',
#   'percentChange': '0.07465600',
#   'quoteVolume': '603.28554543'},
#  'BTC_XCP': {'baseVolume': '9.12904897',
#   'high24hr': '0.00216807',
#   'highestBid': '0.00204205',
#   'id': 108,
#   'isFrozen': '0',
#   'last': '0.00204205',
#   'low24hr': '0.00193028',
#   'lowestAsk': '0.00206239',
#   'percentChange': '0.04635194',
#   'quoteVolume': '4422.83011425'},
#  'BTC_XEM': {'baseVolume': '239.03374270',
#   'high24hr': '0.00004690',
#   'highestBid': '0.00004533',
#   'id': 112,
#   'isFrozen': '0',
#   'last': '0.00004536',
#   'low24hr': '0.00004096',
#   'lowestAsk': '0.00004536',
#   'percentChange': '0.08646706',
#   'quoteVolume': '5516573.58797856'},
#  'BTC_XMR': {'baseVolume': '570.69029893',
#   'high24hr': '0.02729508',
#   'highestBid': '0.02730000',
#   'id': 114,
#   'isFrozen': '0',
#   'last': '0.02730000',
#   'low24hr': '0.02414355',
#   'lowestAsk': '0.02730531',
#   'percentChange': '0.12903179',
#   'quoteVolume': '22619.68548275'},
#  'BTC_XPM': {'baseVolume': '178.74117870',
#   'high24hr': '0.00010395',
#   'highestBid': '0.00009643',
#   'id': 116,
#   'isFrozen': '0',
#   'last': '0.00009692',
#   'low24hr': '0.00009390',
#   'lowestAsk': '0.00009692',
#   'percentChange': '0.02290237',
#   'quoteVolume': '1795428.85585287'},
#  'BTC_XRP': {'baseVolume': '939.08804123',
#   'high24hr': '0.00008450',
#   'highestBid': '0.00008383',
#   'id': 117,
#   'isFrozen': '0',
#   'last': '0.00008387',
#   'low24hr': '0.00008216',
#   'lowestAsk': '0.00008387',
#   'percentChange': '0.01882896',
#   'quoteVolume': '11271923.03270222'},
#  'BTC_XVC': {'baseVolume': '1.13942159',
#   'high24hr': '0.00003735',
#   'highestBid': '0.00003698',
#   'id': 98,
#   'isFrozen': '0',
#   'last': '0.00003716',
#   'low24hr': '0.00003525',
#   'lowestAsk': '0.00003735',
#   'percentChange': '-0.00482056',
#   'quoteVolume': '31313.08815198'},
#  'BTC_ZEC': {'baseVolume': '199.08122213',
#   'high24hr': '0.02834000',
#   'highestBid': '0.02828002',
#   'id': 178,
#   'isFrozen': '0',
#   'last': '0.02843499',
#   'low24hr': '0.02745001',
#   'lowestAsk': '0.02843499',
#   'percentChange': '0.01917526',
#   'quoteVolume': '7155.54166244'},
#  'BTC_ZRX': {'baseVolume': '175.59819959',
#   'high24hr': '0.00010979',
#   'highestBid': '0.00010518',
#   'id': 192,
#   'isFrozen': '0',
#   'last': '0.00010577',
#   'low24hr': '0.00009359',
#   'lowestAsk': '0.00010578',
#   'percentChange': '0.12521276',
#   'quoteVolume': '1689431.08112662'},
#  'ETH_BCH': {'baseVolume': '68.05863811',
#   'high24hr': '1.52311384',
#   'highestBid': '1.51332647',
#   'id': 190,
#   'isFrozen': '0',
#   'last': '1.51895041',
#   'low24hr': '1.49806057',
#   'lowestAsk': '1.52199997',
#   'percentChange': '0.00726229',
#   'quoteVolume': '45.01785558'},
#  'ETH_CVC': {'baseVolume': '16.68947219',
#   'high24hr': '0.00068400',
#   'highestBid': '0.00067914',
#   'id': 195,
#   'isFrozen': '0',
#   'last': '0.00067917',
#   'low24hr': '0.00065639',
#   'lowestAsk': '0.00068398',
#   'percentChange': '0.00632686',
#   'quoteVolume': '24819.96775364'},
#  'ETH_ETC': {'baseVolume': '46.84109209',
#   'high24hr': '0.03249460',
#   'highestBid': '0.03185896',
#   'id': 172,
#   'isFrozen': '0',
#   'last': '0.03185895',
#   'low24hr': '0.03168200',
#   'lowestAsk': '0.03202756',
#   'percentChange': '0.00045816',
#   'quoteVolume': '1465.80645380'},
#  'ETH_GAS': {'baseVolume': '12.38003392',
#   'high24hr': '0.04123498',
#   'highestBid': '0.04098758',
#   'id': 199,
#   'isFrozen': '0',
#   'last': '0.04123497',
#   'low24hr': '0.03999887',
#   'lowestAsk': '0.04123497',
#   'percentChange': '0.03090337',
#   'quoteVolume': '306.94277234'},
#  'ETH_GNO': {'baseVolume': '30.80631746',
#   'high24hr': '0.20570020',
#   'highestBid': '0.19295056',
#   'id': 188,
#   'isFrozen': '0',
#   'last': '0.19680200',
#   'low24hr': '0.18682603',
#   'lowestAsk': '0.19680199',
#   'percentChange': '0.06015002',
#   'quoteVolume': '158.48613229'},
#  'ETH_GNT': {'baseVolume': '109.66698790',
#   'high24hr': '0.00084998',
#   'highestBid': '0.00083582',
#   'id': 186,
#   'isFrozen': '0',
#   'last': '0.00083286',
#   'low24hr': '0.00079000',
#   'lowestAsk': '0.00084749',
#   'percentChange': '0.04985440',
#   'quoteVolume': '133035.11705504'},
#  'ETH_LSK': {'baseVolume': '76.81262391',
#   'high24hr': '0.02160000',
#   'highestBid': '0.02044169',
#   'id': 166,
#   'isFrozen': '0',
#   'last': '0.02043280',
#   'low24hr': '0.02043280',
#   'lowestAsk': '0.02067483',
#   'percentChange': '-0.01992968',
#   'quoteVolume': '3609.80812709'},
#  'ETH_OMG': {'baseVolume': '156.93838653',
#   'high24hr': '0.03102775',
#   'highestBid': '0.02861321',
#   'id': 197,
#   'isFrozen': '0',
#   'last': '0.02861320',
#   'low24hr': '0.02821119',
#   'lowestAsk': '0.02907286',
#   'percentChange': '-0.07250537',
#   'quoteVolume': '5335.87345811'},
#  'ETH_REP': {'baseVolume': '38.29090608',
#   'high24hr': '0.05799123',
#   'highestBid': '0.05764374',
#   'id': 176,
#   'isFrozen': '0',
#   'last': '0.05797361',
#   'low24hr': '0.05683430',
#   'lowestAsk': '0.05797362',
#   'percentChange': '0.01019682',
#   'quoteVolume': '667.11024152'},
#  'ETH_STEEM': {'baseVolume': '3.51387854',
#   'high24hr': '0.00503381',
#   'highestBid': '0.00489437',
#   'id': 169,
#   'isFrozen': '0',
#   'last': '0.00489437',
#   'low24hr': '0.00488801',
#   'lowestAsk': '0.00489786',
#   'percentChange': '-0.01371704',
#   'quoteVolume': '709.73336004'},
#  'ETH_ZEC': {'baseVolume': '13.57254518',
#   'high24hr': '0.44247210',
#   'highestBid': '0.44188348',
#   'id': 179,
#   'isFrozen': '0',
#   'last': '0.44247210',
#   'low24hr': '0.43288777',
#   'lowestAsk': '0.44247210',
#   'percentChange': '0.00529573',
#   'quoteVolume': '30.95077832'},
#  'ETH_ZRX': {'baseVolume': '144.30624419',
#   'high24hr': '0.00171663',
#   'highestBid': '0.00164152',
#   'id': 193,
#   'isFrozen': '0',
#   'last': '0.00164500',
#   'low24hr': '0.00147841',
#   'lowestAsk': '0.00164500',
#   'percentChange': '0.11901716',
#   'quoteVolume': '88660.56797419'},
#  'USDT_BCH': {'baseVolume': '657959.30774854',
#   'high24hr': '787.38114730',
#   'highestBid': '771.17361193',
#   'id': 191,
#   'isFrozen': '0',
#   'last': '771.17361193',
#   'low24hr': '752.12671106',
#   'lowestAsk': '773.80690397',
#   'percentChange': '0.01152769',
#   'quoteVolume': '853.16829505'},
#  'USDT_BTC': {'baseVolume': '13052988.37730839',
#   'high24hr': '8168.57040884',
#   'highestBid': '7928.00000000',
#   'id': 121,
#   'isFrozen': '0',
#   'last': '7928.00000000',
#   'low24hr': '7830.98999999',
#   'lowestAsk': '7938.00828524',
#   'percentChange': '-0.01153453',
#   'quoteVolume': '1631.19814459'},
#  'USDT_DASH': {'baseVolume': '210194.26533950',
#   'high24hr': '379.40269365',
#   'highestBid': '362.34002634',
#   'id': 122,
#   'isFrozen': '0',
#   'last': '370.59976766',
#   'low24hr': '359.20686822',
#   'lowestAsk': '370.59976764',
#   'percentChange': '0.02597065',
#   'quoteVolume': '569.11936990'},
#  'USDT_ETC': {'baseVolume': '884194.76354473',
#   'high24hr': '16.84147000',
#   'highestBid': '16.15219563',
#   'id': 173,
#   'isFrozen': '0',
#   'last': '16.19893740',
#   'low24hr': '16.00000000',
#   'lowestAsk': '16.19829617',
#   'percentChange': '0.00055203',
#   'quoteVolume': '54161.68470722'},
#  'USDT_ETH': {'baseVolume': '2995792.24192808',
#   'high24hr': '521.49105740',
#   'highestBid': '507.20099527',
#   'id': 149,
#   'isFrozen': '0',
#   'last': '508.49952389',
#   'low24hr': '500.91320280',
#   'lowestAsk': '508.49491613',
#   'percentChange': '0.00295764',
#   'quoteVolume': '5877.61663484'},
#  'USDT_LTC': {'baseVolume': '1832931.53390071',
#   'high24hr': '140.46577577',
#   'highestBid': '136.90000000',
#   'id': 123,
#   'isFrozen': '0',
#   'last': '136.90000000',
#   'low24hr': '128.99388089',
#   'lowestAsk': '136.96466839',
#   'percentChange': '0.05307692',
#   'quoteVolume': '13505.76435325'},
#  'USDT_NXT': {'baseVolume': '762251.13760199',
#   'high24hr': '0.19824482',
#   'highestBid': '0.18687128',
#   'id': 124,
#   'isFrozen': '0',
#   'last': '0.18799505',
#   'low24hr': '0.18011001',
#   'lowestAsk': '0.18799416',
#   'percentChange': '0.01386967',
#   'quoteVolume': '4032734.85108143'},
#  'USDT_REP': {'baseVolume': '75256.75276696',
#   'high24hr': '29.79554766',
#   'highestBid': '29.27333370',
#   'id': 175,
#   'isFrozen': '0',
#   'last': '29.49999890',
#   'low24hr': '28.77262499',
#   'lowestAsk': '29.49999449',
#   'percentChange': '0.00785783',
#   'quoteVolume': '2568.80887791'},
#  'USDT_STR': {'baseVolume': '3634846.36540070',
#   'high24hr': '0.32000000',
#   'highestBid': '0.30650000',
#   'id': 125,
#   'isFrozen': '0',
#   'last': '0.30650001',
#   'low24hr': '0.28198670',
#   'lowestAsk': '0.30820102',
#   'percentChange': '0.07472576',
#   'quoteVolume': '11946875.03177268'},
#  'USDT_XMR': {'baseVolume': '395101.03874625',
#   'high24hr': '215.95000000',
#   'highestBid': '214.06689457',
#   'id': 126,
#   'isFrozen': '0',
#   'last': '215.39138321',
#   'low24hr': '193.00000292',
#   'lowestAsk': '215.39138321',
#   'percentChange': '0.10708771',
#   'quoteVolume': '1966.80919955'},
#  'USDT_XRP': {'baseVolume': '3814802.28427684',
#   'high24hr': '0.68184902',
#   'highestBid': '0.66500000',
#   'id': 127,
#   'isFrozen': '0',
#   'last': '0.66593993',
#   'low24hr': '0.64969000',
#   'lowestAsk': '0.66590920',
#   'percentChange': '0.00717755',
#   'quoteVolume': '5735428.56832054'},
#  'USDT_ZEC': {'baseVolume': '214183.31888006',
#   'high24hr': '228.80929560',
#   'highestBid': '224.00000003',
#   'id': 180,
#   'isFrozen': '0',
#   'last': '225.00000000',
#   'low24hr': '219.55865982',
#   'lowestAsk': '225.07129693',
#   'percentChange': '0.00832386',
#   'quoteVolume': '953.61319883'},
#  'XMR_BCN': {'baseVolume': '2.08016129',
#   'high24hr': '0.00002220',
#   'highestBid': '0.00001923',
#   'id': 129,
#   'isFrozen': '0',
#   'last': '0.00001930',
#   'low24hr': '0.00001930',
#   'lowestAsk': '0.00001986',
#   'percentChange': '-0.04360753',
#   'quoteVolume': '101282.15764894'},
#  'XMR_BLK': {'baseVolume': '17.56282048',
#   'high24hr': '0.00143104',
#   'highestBid': '0.00127248',
#   'id': 130,
#   'isFrozen': '0',
#   'last': '0.00127491',
#   'low24hr': '0.00127788',
#   'lowestAsk': '0.00129774',
#   'percentChange': '-0.10910247',
#   'quoteVolume': '12914.17489577'},
#  'XMR_BTCD': {'baseVolume': '5.34216158',
#   'high24hr': '0.30554593',
#   'highestBid': '0.28257849',
#   'id': 131,
#   'isFrozen': '0',
#   'last': '0.28257847',
#   'low24hr': '0.28257847',
#   'lowestAsk': '0.29479807',
#   'percentChange': '-0.05305078',
#   'quoteVolume': '17.73814796'},
#  'XMR_DASH': {'baseVolume': '16.82192418',
#   'high24hr': '1.89176143',
#   'highestBid': '1.70799613',
#   'id': 132,
#   'isFrozen': '0',
#   'last': '1.70799613',
#   'low24hr': '1.70799613',
#   'lowestAsk': '1.73380935',
#   'percentChange': '-0.08142619',
#   'quoteVolume': '9.40404201'},
#  'XMR_LTC': {'baseVolume': '121.88799727',
#   'high24hr': '0.70999983',
#   'highestBid': '0.63000033',
#   'id': 137,
#   'isFrozen': '0',
#   'last': '0.63000000',
#   'low24hr': '0.63000000',
#   'lowestAsk': '0.63679642',
#   'percentChange': '-0.05485884',
#   'quoteVolume': '181.12339206'},
#  'XMR_MAID': {'baseVolume': '20.04860763',
#   'high24hr': '0.00178910',
#   'highestBid': '0.00158842',
#   'id': 138,
#   'isFrozen': '0',
#   'last': '0.00159071',
#   'low24hr': '0.00159071',
#   'lowestAsk': '0.00159995',
#   'percentChange': '-0.06325230',
#   'quoteVolume': '12392.53226107'},
#  'XMR_NXT': {'baseVolume': '54.00957850',
#   'high24hr': '0.00100308',
#   'highestBid': '0.00086605',
#   'id': 140,
#   'isFrozen': '0',
#   'last': '0.00086667',
#   'low24hr': '0.00086780',
#   'lowestAsk': '0.00086701',
#   'percentChange': '-0.07790273',
#   'quoteVolume': '55143.17996546'},
#  'XMR_ZEC': {'baseVolume': '74.87746139',
#   'high24hr': '1.15300369',
#   'highestBid': '1.04542765',
#   'id': 181,
#   'isFrozen': '0',
#   'last': '1.04644000',
#   'low24hr': '1.04644000',
#   'lowestAsk': '1.04644000',
#   'percentChange': '-0.08944592',
#   'quoteVolume': '67.06344898'}}

# %% [markdown]
# Great! Have regigged this to work with Python3.6. And I can use `tickers.keys()` to extract all of the currency pairs and pass these onto getting candle chart data. However, note that the PoloniexAPI.py file does not have returnChartData() implemented, I will need to do this myself.
